# %%
import pandas as pd
import time
import numpy as np
import os
import random
from datetime import datetime   
import math
from tqdm.notebook  import tqdm
from shutil import copytree

pd.options.mode.chained_assignment  = None

# %%
# Define the path for all of the folders.
ED_FOLDER_PATH = "E:/AI-VR dataset/MIMIC-IV ED"
CLINICAL_FOLDER_PATH = "E:/AI-VR dataset/MIMIC-IV Clinical Database"
CXR_FOLDER_PATH = "E:/AI-VR dataset/MIMIC-CXR-JPG/physionet.org/files/mimic-cxr-jpg/2.0.0"
EYEGAZE_FOLDER_PATH = "E:/AI-VR dataset/eye-gaze-data-for-chest-x-rays-1.0.0"
REFLACX_FOLDER_PATH = "E:/AI-VR dataset/reflacx-reports-and-eye-tracking-data-for-localization-of-abnormalities-in-chest-x-rays-1.0.0/reflacx-reports-and-eye-tracking-data-for-localization-of-abnormalities-in-chest-x-rays-1.0.0"
# XAMI_MIMIC_PATH = "E:/AI-VR dataset/XAMI-MIMIC"
XAMI_MIMIC_PATH = "./XAMI-MIMIC"

# %%
cxr_df_with_stay_id_only = pd.read_csv("cxr_meta_with_stay_id_only.csv", index_col=0)
cxr_df_with_stay_id_only.head(5)
# Out:
#                                        dicom_id  subject_id  study_id  \
# 0  02aa804e-bde0afdd-112c0b34-7bc16630-4e384014    10000032  50414267
# 1  174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962    10000032  50414267
# 2  2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab    10000032  53189527
# 3  e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c    10000032  53189527
# 6  ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c    10000032  56699142
#
#   PerformedProcedureStepDescription ViewPosition  Rows  Columns  StudyDate  \
# 0                CHEST (PA AND LAT)           PA  3056     2544   21800506
# 1                CHEST (PA AND LAT)      LATERAL  3056     2544   21800506
# 2                CHEST (PA AND LAT)           PA  3056     2544   21800626
# 3                CHEST (PA AND LAT)      LATERAL  3056     2544   21800626
# 6               CHEST (PORTABLE AP)           AP  3056     2544   21800805
#
#     StudyTime ProcedureCodeSequence_CodeMeaning ViewCodeSequence_CodeMeaning  \
# 0  213014.531                CHEST (PA AND LAT)             postero-anterior
# 1  213014.531                CHEST (PA AND LAT)                      lateral
# 2  165500.312                CHEST (PA AND LAT)             postero-anterior
# 3  165500.312                CHEST (PA AND LAT)                      lateral
# 6  234424.765               CHEST (PORTABLE AP)             antero-posterior
#
#   PatientOrientationCodeSequence_CodeMeaning  StudyDateTime   stay_id  \
# 0                                      Erect   2.180051e+13  33258284
# 1                                      Erect   2.180051e+13  33258284
# 2                                      Erect   2.180063e+13  38112554
# 3                                      Erect   2.180063e+13  38112554
# 6                                        NaN   2.180081e+13  35968195
#
#    in_eye_gaze  in_reflacx  in_ed  in_core
# 0        False       False   True     True
# 1        False       False   True     True
# 2        False       False   True     True
# 3        False       False   True     True
# 6        False       False   True     True

# %%
reflacx_meta_df =  pd.concat([pd.read_csv(f"{REFLACX_FOLDER_PATH}/main_data/metadata_phase_{i}.csv") for i in range(1,4)])

# %%
reflacx_meta_df.to_csv("reflacx_metadata.csv")

# %%
def get_subjectId_and_stayId_by_dicomId(cxr_df, dicom_id):
    matches = cxr_df[cxr_df['dicom_id'] == dicom_id]

    if (len(matches)> 0):
        return matches.iloc[0]['subject_id'], matches.iloc[0]['stay_id']

    return None

# %%
def get_cxr_match_by_dicom_ids(cxr_df, dicom_ids):
    matches = cxr_df[cxr_df['dicom_id'].isin(dicom_ids)]
    return matches

# %%
all_valid_dicom_id_with_stay_id_indentified = set(cxr_df_with_stay_id_only['dicom_id'])

# %%
reflacx_meta__df_with_stay_id_indentified =  reflacx_meta_df[reflacx_meta_df['dicom_id'].isin(all_valid_dicom_id_with_stay_id_indentified)]

# %%
reflacx_meta__df_with_stay_id_indentified
# Out:
#                id  split  eye_tracking_data_discarded  \
# 0     P102R108387  train                        False
# 1     P102R379837  train                        False
# 2     P102R558314  train                        False
# 3     P102R765317  train                        False
# 4     P102R915878  train                        False
# ...           ...    ...                          ...
# 2475  P300R833708  train                        False
# 2478  P300R918521  train                        False
# 2482  P300R611251  train                        False
# 2483  P300R519683   test                        False
# 2494  P300R827738  train                        False
#
#                                                   image  \
# 0     physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# 1     physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# 2     physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# 3     physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# 4     physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# ...                                                 ...
# 2475  physionet.org/files/mimic-cxr/2.0.0/files/p19/...
# 2478  physionet.org/files/mimic-cxr/2.0.0/files/p19/...
# 2482  physionet.org/files/mimic-cxr/2.0.0/files/p19/...
# 2483  physionet.org/files/mimic-cxr/2.0.0/files/p19/...
# 2494  physionet.org/files/mimic-cxr/2.0.0/files/p19/...
#
#                                           dicom_id  subject_id  image_size_x  \
# 0     34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# 1     34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# 2     34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# 3     34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# 4     34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# ...                                            ...         ...           ...
# 2475  a2fe8aae-2fe32131-b47c4e5b-090f4c13-88e7ac97    19875621          2544
# 2478  a2a80c63-8b9575dc-bc08895e-40392d6a-d7fc17d5    19884194          2544
# 2482  2b20dcdf-4077bc16-48fc8eb5-265ef218-f6552cb0    19906407          2881
# 2483  92134f99-0e73faba-1280ad81-218c68ba-933a85c5    19907884          2544
# 2494  bd356a66-7c03720a-c5227633-82282d68-914e93c4    19957626          2544
#
#       image_size_y  Airway wall thickening  Atelectasis  ...  Support devices  \
# 0             3056                     0.0          0.0  ...             True
# 1             3056                     0.0          0.0  ...             True
# 2             3056                     4.0          0.0  ...             True
# 3             3056                     0.0          0.0  ...             True
# 4             3056                     0.0          0.0  ...             True
# ...            ...                     ...          ...  ...              ...
# 2475          3056                     NaN          0.0  ...            False
# 2478          3056                     NaN          0.0  ...            False
# 2482          2544                     NaN          0.0  ...             True
# 2483          3056                     NaN          0.0  ...            False
# 2494          3056                     NaN          0.0  ...             True
#
#       Wide mediastinum  Abnormal mediastinal contour  Acute fracture  \
# 0                  0.0                           NaN             NaN
# 1                  0.0                           NaN             NaN
# 2                  0.0                           NaN             NaN
# 3                  2.0                           NaN             NaN
# 4                  0.0                           NaN             NaN
# ...                ...                           ...             ...
# 2475               NaN                           0.0             0.0
# 2478               NaN                           0.0             0.0
# 2482               NaN                           2.0             0.0
# 2483               NaN                           0.0             0.0
# 2494               NaN                           0.0             0.0
#
#       Enlarged hilum  Hiatal hernia  High lung volume / emphysema  \
# 0                NaN            NaN                           NaN
# 1                NaN            NaN                           NaN
# 2                NaN            NaN                           NaN
# 3                NaN            NaN                           NaN
# 4                NaN            NaN                           NaN
# ...              ...            ...                           ...
# 2475             0.0            0.0                           0.0
# 2478             0.0            0.0                           0.0
# 2482             0.0            0.0                           0.0
# 2483             0.0            0.0                           0.0
# 2494             0.0            0.0                           0.0
#
#       Interstitial lung disease Lung nodule or mass  Pleural abnormality
# 0                           NaN                 NaN                  NaN
# 1                           NaN                 NaN                  NaN
# 2                           NaN                 NaN                  NaN
# 3                           NaN                 NaN                  NaN
# 4                           NaN                 NaN                  NaN
# ...                         ...                 ...                  ...
# 2475                        0.0                 0.0                  0.0
# 2478                        0.0                 0.0                  0.0
# 2482                        0.0                 0.0                  0.0
# 2483                        0.0                 0.0                  0.0
# 2494                        0.0                 0.0                  0.0
#
# [674 rows x 34 columns]

# %%
print(f"We have {len(reflacx_meta__df_with_stay_id_indentified)} in the REFLACX dataset can be used with clinical data.")
# Out:
# We have 674 in the REFLACX dataset can be used with clinical data.

# %%
reflacx_meta__df_with_stay_id_indentified.head(5)
# Out:
#             id  split  eye_tracking_data_discarded  \
# 0  P102R108387  train                        False
# 1  P102R379837  train                        False
# 2  P102R558314  train                        False
# 3  P102R765317  train                        False
# 4  P102R915878  train                        False
#
#                                                image  \
# 0  physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# 1  physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# 2  physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# 3  physionet.org/files/mimic-cxr/2.0.0/files/p18/...
# 4  physionet.org/files/mimic-cxr/2.0.0/files/p18/...
#
#                                        dicom_id  subject_id  image_size_x  \
# 0  34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# 1  34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# 2  34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# 3  34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
# 4  34cedb74-d0996b40-6d218312-a9174bea-d48dc033    18111516          2544
#
#    image_size_y  Airway wall thickening  Atelectasis  ...  Support devices  \
# 0          3056                     0.0          0.0  ...             True
# 1          3056                     0.0          0.0  ...             True
# 2          3056                     4.0          0.0  ...             True
# 3          3056                     0.0          0.0  ...             True
# 4          3056                     0.0          0.0  ...             True
#
#    Wide mediastinum  Abnormal mediastinal contour  Acute fracture  \
# 0               0.0                           NaN             NaN
# 1               0.0                           NaN             NaN
# 2               0.0                           NaN             NaN
# 3               2.0                           NaN             NaN
# 4               0.0                           NaN             NaN
#
#    Enlarged hilum  Hiatal hernia  High lung volume / emphysema  \
# 0             NaN            NaN                           NaN
# 1             NaN            NaN                           NaN
# 2             NaN            NaN                           NaN
# 3             NaN            NaN                           NaN
# 4             NaN            NaN                           NaN
#
#    Interstitial lung disease Lung nodule or mass  Pleural abnormality
# 0                        NaN                 NaN                  NaN
# 1                        NaN                 NaN                  NaN
# 2                        NaN                 NaN                  NaN
# 3                        NaN                 NaN                  NaN
# 4                        NaN                 NaN                  NaN
#
# [5 rows x 34 columns]

# %%
all_patients_to_import = list(set(reflacx_meta__df_with_stay_id_indentified['subject_id']))

# %%
for subject_id in all_patients_to_import:
    subject_match = reflacx_meta__df_with_stay_id_indentified[reflacx_meta__df_with_stay_id_indentified["subject_id"] == subject_id]
    all_dicom_ids = list(subject_match['dicom_id'])
    cxr_matches = get_cxr_match_by_dicom_ids(cxr_df_with_stay_id_only ,all_dicom_ids)
    all_stay_ids = list(set(cxr_matches['stay_id']))
    
    for stay_id in all_stay_ids:
        dicom_ids_for_this_stay = list(cxr_matches[cxr_matches['stay_id'] == stay_id]['dicom_id'])
        match_meta_df = reflacx_meta__df_with_stay_id_indentified[reflacx_meta__df_with_stay_id_indentified['dicom_id'].isin(dicom_ids_for_this_stay)]

        save_folder_path = f"{XAMI_MIMIC_PATH}/patient_{subject_id}/stay_{stay_id}/REFLACX"
        os.makedirs(save_folder_path, exist_ok=True)

        match_meta_df.to_csv(f"{save_folder_path}/metadata.csv")

        all_study_ids = list(match_meta_df['id'])

        for study_id in all_study_ids:
            source_path = f"{REFLACX_FOLDER_PATH}/main_data/{study_id}"
            destination_path = f"{save_folder_path}/{study_id}"
            copytree(source_path, destination_path)
