# %%
import pandas as pd

# %%
cxr_df = pd.read_csv('mimic-eye/spreadsheets/cxr_meta.csv')

# %%
cxr_df
# Out:
#       Unnamed: 0                                      dicom_id  subject_id  \
# 0            177  fa771fa1-d9571d07-bff8f655-327734a7-6e10b29d    10002428
# 1            181  4873aa08-977bfd31-fb492e64-6ef432d1-3f12cbe3    10002430
# 2            266  dcdc4bd9-4301b111-2a65a814-ee8e7bc5-7f0b9a5a    10003400
# 3            497  5bdabba9-388f6646-ac06b5f5-f68b2fd2-3630de21    10011607
# 4            539  4a629500-9c3281ca-90bab490-9b6ac9c1-e5e6a580    10012261
# ...          ...                                           ...         ...
# 3684      376634  d9661ff6-877ac981-a20a8810-92309d46-173008ad    19991135
# 3685      376636  d8f5555c-d8bcf97c-3a9d5596-17b9f854-6e15d081    19991135
# 3686      376644  d04bbcbd-5143439e-50ebe9a8-71380f67-44f8d127    19991135
# 3687      377010  7cfe7acc-65b0b548-feb77772-04c46d33-76a03230    19997367
# 3688      377014  1bdf3180-0209f001-967acab6-0b811ea2-3c2e13eb    19997367
#
# ...

# %%
cxr_df[cxr_df['dicom_id'].apply(lambda x: x.startswith("1e4d4d01-657d797c-f09f7a14-cc14e092-909"))]
# Out:
#       Unnamed: 0                                      dicom_id  subject_id  \
# 2256      235601  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8    16239007
#
#       study_id PerformedProcedureStepDescription ViewPosition  Rows  Columns  \
# 2256  56501990                CHEST (PA AND LAT)           PA  2544     3056
#
#       StudyDate   StudyTime ProcedureCodeSequence_CodeMeaning  \
# 2256   21810619  211844.562                CHEST (PA AND LAT)
#
#      ViewCodeSequence_CodeMeaning PatientOrientationCodeSequence_CodeMeaning  \
# 2256             postero-anterior                                      Erect
#
#       in_eye_gaze  in_reflacx  StudyDateTime     stay_id
# 2256         True       False   2.181062e+13  30225205.0

# %%
g_df = pd.read_csv("/Users/jrhs/Documents/GitHub/MIMIC-Eye/mimic-eye/patient_16239007/EyeGaze/eye_gaze.csv")

# %%
g_df[g_df["DICOM_ID"] == "1e4d4d01-657d797c-f09f7a14-cc14e092-909"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, SESSION_ID, MEDIA_ID, DICOM_ID, CNT, Time (in secs), TIMETICK(f=10000000), FPOGX, FPOGY, FPOGS, FPOGD, FPOGID, FPOGV, BPOGX, BPOGY, BPOGV, LPCX, LPCY, LPD, LPS, LPV, RPCX, RPCY, RPD, RPS, RPV, BKID, BKDUR, BKPMIN, LPMM, LPMMV, RPMM, RPMMV, SACCADE_MAG, SACCADE_DIR, VID_FRAME, X_ORIGINAL, Y_ORIGINAL]
# Index: []
#
# [0 rows x 38 columns]

# %%
g_df[g_df["DICOM_ID"] == "1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8"]
# Out:
#       Unnamed: 0  SESSION_ID  MEDIA_ID  \
# 1414     1050710          31         3
# 1415     1050711          31         3
# 1416     1050712          31         3
# 1417     1050713          31         3
# 1418     1050714          31         3
# ...          ...         ...       ...
# 2703     1051999          31         3
# 2704     1052000          31         3
# 2705     1052001          31         3
# 2706     1052002          31         3
# 2707     1052003          31         3
#
#                                           DICOM_ID   CNT  Time (in secs)  \
# 1414  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     0         0.00000
# 1415  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     1         0.01546
# 1416  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     2         0.03145
# 1417  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     3         0.04808
# 1418  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     4         0.06403
# ...

# %%
egd_df = pd.read_csv("/Users/jrhs/Desktop/physionet.org/files/egd-cxr/1.0.0/eye_gaze.csv")

# %%
egd_df[egd_df['DICOM_ID'] == "1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8"]
# Out:
#          SESSION_ID  MEDIA_ID                                      DICOM_ID  \
# 1050710          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# 1050711          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# 1050712          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# 1050713          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# 1050714          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# ...             ...       ...                                           ...
# 1051999          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# 1052000          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# 1052001          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# 1052002          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
# 1052003          31         3  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8
#
# ...

# %%
egd_df[egd_df['DICOM_ID'] == "1e4d4d01-657d797c-f09f7a14-cc14e092-909"] # has the wrong one, not imported into our mimic-eye
# Out:
#       SESSION_ID  MEDIA_ID                                 DICOM_ID  CNT  \
# 1060           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909    0
# 1061           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909    1
# 1062           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909    2
# 1063           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909    3
# 1064           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909    4
# ...          ...       ...                                      ...  ...
# 1130           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909   70
# 1131           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909   71
# 1132           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909   72
# 1133           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909   73
# 1134           1         1  1e4d4d01-657d797c-f09f7a14-cc14e092-909   74
#
#       Time (in secs)  TIMETICK(f=10000000)    FPOGX    FPOGY    FPOGS  \
# ...

# %%
g_df[g_df["DICOM_ID"] == "1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8"]
# Out:
#       Unnamed: 0  SESSION_ID  MEDIA_ID  \
# 1414     1050710          31         3
# 1415     1050711          31         3
# 1416     1050712          31         3
# 1417     1050713          31         3
# 1418     1050714          31         3
# ...          ...         ...       ...
# 2703     1051999          31         3
# 2704     1052000          31         3
# 2705     1052001          31         3
# 2706     1052002          31         3
# 2707     1052003          31         3
#
#                                           DICOM_ID   CNT  Time (in secs)  \
# 1414  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     0         0.00000
# 1415  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     1         0.01546
# 1416  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     2         0.03145
# 1417  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     3         0.04808
# 1418  1e4d4d01-657d797c-f09f7a14-cc14e092-909e66b8     4         0.06403
# ...

# %%
egd_df[egd_df['DICOM_ID'] == "d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf"] # has the wrong one, not imported into our mimic-eye
# Out:
#        SESSION_ID  MEDIA_ID                                 DICOM_ID  CNT  \
# 91025           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf    0
# 91026           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf    1
# 91027           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf    2
# 91028           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf    3
# 91029           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf    4
# ...           ...       ...                                      ...  ...
# 91258           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf  233
# 91259           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf  234
# 91260           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf  235
# 91261           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf  236
# 91262           3        25  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf  237
#
#        Time (in secs)  TIMETICK(f=10000000)    FPOGX    FPOGY    FPOGS  \
# ...

# %%
cxr_df[cxr_df['dicom_id'].apply(lambda x: x.startswith("d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdf"))]
# Out:
#       Unnamed: 0                                      dicom_id  subject_id  \
# 2605      268165  d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdfce462    17114989
#
#       study_id PerformedProcedureStepDescription ViewPosition  Rows  Columns  \
# 2605  57530456                CHEST (PA AND LAT)           PA  3056     2544
#
#       StudyDate  StudyTime ProcedureCodeSequence_CodeMeaning  \
# 2605   21661123  112341.75                CHEST (PA AND LAT)
#
#      ViewCodeSequence_CodeMeaning PatientOrientationCodeSequence_CodeMeaning  \
# 2605             postero-anterior                                      Erect
#
#       in_eye_gaze  in_reflacx  StudyDateTime     stay_id
# 2605         True       False   2.166112e+13  36958669.0

# %%
g_df[g_df["DICOM_ID"] == "d3a43470-e8e4b5c1-c68c59e1-da71f25a-bdfce462"] # No here.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, SESSION_ID, MEDIA_ID, DICOM_ID, CNT, Time (in secs), TIMETICK(f=10000000), FPOGX, FPOGY, FPOGS, FPOGD, FPOGID, FPOGV, BPOGX, BPOGY, BPOGV, LPCX, LPCY, LPD, LPS, LPV, RPCX, RPCY, RPD, RPS, RPV, BKID, BKDUR, BKPMIN, LPMM, LPMMV, RPMM, RPMMV, SACCADE_MAG, SACCADE_DIR, VID_FRAME, X_ORIGINAL, Y_ORIGINAL]
# Index: []
#
# [0 rows x 38 columns]

# %%
egd_df[egd_df['DICOM_ID'] == "826178de-61e5f340-cd1a808b-301b85ff"] # has the wrong one, not imported into our mimic-eye
# Out:
#         SESSION_ID  MEDIA_ID                             DICOM_ID  CNT  \
# 156241           5        15  826178de-61e5f340-cd1a808b-301b85ff    0
# 156242           5        15  826178de-61e5f340-cd1a808b-301b85ff    1
# 156243           5        15  826178de-61e5f340-cd1a808b-301b85ff    2
# 156244           5        15  826178de-61e5f340-cd1a808b-301b85ff    3
# 156245           5        15  826178de-61e5f340-cd1a808b-301b85ff    4
# ...            ...       ...                                  ...  ...
# 156519           5        15  826178de-61e5f340-cd1a808b-301b85ff  278
# 156520           5        15  826178de-61e5f340-cd1a808b-301b85ff  279
# 156521           5        15  826178de-61e5f340-cd1a808b-301b85ff  280
# 156522           5        15  826178de-61e5f340-cd1a808b-301b85ff  281
# 156523           5        15  826178de-61e5f340-cd1a808b-301b85ff  282
#
#         Time (in secs)  TIMETICK(f=10000000)    FPOGX    FPOGY    FPOGS  \
# ...

# %%
cxr_df[cxr_df['dicom_id'].apply(lambda x: x.startswith("826178de-61e5f340-cd1a808b-301b85ff"))]
# Out:
#       Unnamed: 0                                      dicom_id  subject_id  \
# 3623      369874  826178de-61e5f340-cd1a808b-301b85ff-22320d04    19808040
#
#       study_id PerformedProcedureStepDescription ViewPosition  Rows  Columns  \
# 3623  50402519                CHEST (PA AND LAT)           PA  3056     2544
#
#       StudyDate   StudyTime ProcedureCodeSequence_CodeMeaning  \
# 3623   21430814  160625.125                CHEST (PA AND LAT)
#
#      ViewCodeSequence_CodeMeaning PatientOrientationCodeSequence_CodeMeaning  \
# 3623             postero-anterior                                      Erect
#
#       in_eye_gaze  in_reflacx  StudyDateTime     stay_id
# 3623         True       False   2.143081e+13  35367822.0

# %%
egd_df[egd_df['DICOM_ID'] == "826178de-61e5f340-cd1a808b-301b85ff-22320d04"] # has the wrong one, not imported into our mimic-eye
# Out:
#         SESSION_ID  MEDIA_ID                                      DICOM_ID  \
# 156524           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# 156525           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# 156526           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# 156527           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# 156528           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# ...            ...       ...                                           ...
# 157588           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# 157589           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# 157590           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# 157591           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
# 157592           5        16  826178de-61e5f340-cd1a808b-301b85ff-22320d04
#
# ...
